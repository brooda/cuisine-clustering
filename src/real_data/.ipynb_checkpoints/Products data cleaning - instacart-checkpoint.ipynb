# %%
import numpy as np
import pandas as pd
import re
from collections import Counter

# %%
flatten = lambda l: [item for sublist in l for item in sublist]

# %% [markdown]
# ## Filtering / cleaning functions

# %%
def not_has_numbers(inputString):
    return not any(char.isdigit() for char in inputString)

def not_one_or_two_letter(inputString):
    return len(inputString) > 2

# %%
def change_to_singular(inputString):
    inputString = re.sub('ies$', 'y', inputString)
    inputString = re.sub('es$', '', inputString)
    inputString = re.sub('s$', '', inputString)
    
    return inputString

# %%
def filter_and_normalize_list(words_list):
    words_list = filter(not_has_numbers, words_list)
    words_list = filter(not_one_or_two_letter, words_list)
    words_list = map(change_to_singular, words_list)
    words_list = map(lambda x: x.lower(), words_list)
    
    return list(words_list)

# %% [markdown]
# ## Products bought in supermarket

# %%
exec(open("allowed_aisles.txt").read())
products = pd.read_csv("../../data/instacart/products.csv")
products = products[products.aisle_id.isin(allowed_aisles)]
names = products.product_name.str.lower().tolist()

# %%
products
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 4               5                          Green Chile Anytime Sauce
# 6               7                     Pure Coconut Water With Orange
# 7               8                  Cut Russet Potatoes Steam N' Mash
# 8               9                  Light Strawberry Blueberry Yogurt
# 10             11                                  Peach Mango Juice
# 16             17                                  Rendered Duck Fat
# 18             19   Gluten Free Quinoa Three Cheese & Mushroom Blend
# 19             20     Pomegranate Cranberry & Aloe Vera Enrich Drink
# 22             23                             Organic Turkey Burgers
# 27             28                                  Wheat Chex Cereal
# 28             29  Fresh Cut Golden Sweet No Salt Added Whole Ker...
# 30             31                                 White Pearl Onions
# 32             33                      Organic Spaghetti Style Pasta
# 33             34                               Peanut Butter Cereal
# 34             35     Italian Herb Porcini Mushrooms Chicken Sausage
# 36             37                 Noodle Soup Mix With Chicken Broth
# 39             40  Beef Hot Links Beef Smoked Sausage With Chile ...
# 42             43                                Organic Clementines
# 44             45                                  European Cucumber
# 45             46                     Raisin Cinnamon Bagels 5 count
# 46             47         Onion Flavor Organic Roasted Seaweed Snack
# 48             49      Vegetarian Grain Meat Sausages Italian - 4 CT
# 49             50                                 Pumpkin Muffin Mix
# 51             52                                Mirabelle Brut Rose
# 52             53              Whole Leaf Pure Aloe With Lemon Juice
# 57             58                              Whole Wheat Tortillas
# 58             59               Medium Taqueria Style Chipotle Salsa
# 59             60     Cheesy Creations Roasted Garlic Parmesan Sauce
# ...           ...                                                ...
# 49634       49635   Baby Food Blueberry, Parsnip & Buckwheat Stage 2
# 49635       49636                       Vegetable & Chicken Dumpling
# 49636       49637  Passion Fruit Flavored Fruit Juice Cocktail Blend
# 49637       49638               Organic Superfirm Vacuum Packed Tofu
# 49638       49639                       Pecans, Maple, Premium Blend
# 49641       49642                                     Candy Eyeballs
# 49642       49643                    Tomatillo Salsa Cranberry-Mango
# 49643       49644                                      Feta Crumbles
# 49647       49648                               Squid Ink Fettuccini
# 49650       49651                                       Beef Brisket
# 49653       49654                   Teriyaki Sauce, Sesame, Original
# 49654       49655                                        Apple Cider
# 49655       49656                         Masada Kosher Pocket Bread
# 49656       49657                                  Cabernet Tomatoes
# 49657       49658                         Brie with Herbs Foil Wedge
# 49658       49659                            Organic Creamed Coconut
# 49660       49661                                              Porto
# 49664       49665      Super Dark Coconut Ash & Banana Chocolate Bar
# 49665       49666                      Ginger Snaps Snacking Cookies
# 49669       49670                                Beef Summer Sausage
# 49670       49671                               Milk Chocolate Drops
# 49672       49673              Stone Baked Multi Grain Artisan Rolls
# 49676       49677                    Thick & Chunky Sloppy Joe Sauce
# 49677       49678                    Large Chicken & Cheese Taquitos
# 49678       49679                            Famous Chocolate Wafers
# 49679       49680                 All Natural Creamy Caesar Dressing
# 49681       49682                                 California Limeade
# 49682       49683                                     Cucumber Kirby
# 49683       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49684       49685                 En Croute Roast Hazelnut Cranberry
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 4             5             13
# 6            98              7
# 7           116              1
# 8           120             16
# 10           31              7
# 16           35             12
# 18           63              9
# 19           98              7
# 22           49             12
# 27          121             14
# 28           81             15
# 30          123              4
# 32          131              9
# 33          121             14
# 34          106             12
# 36           69             15
# 39          106             12
# 42          123              4
# 44           83              4
# 45           58              1
# 46           66              6
# 48           14             20
# 49          105             13
# 51          134              5
# 52           98              7
# 57          128              3
# 58           50             19
# 59            9              9
# ...         ...            ...
# 49634        83              4
# 49635       129              1
# 49636        31              7
# 49637        14             20
# 49638       117             19
# 49641        97             13
# 49642        51             13
# 49643         2             16
# 49647       131              9
# 49650       122             12
# 49653         5             13
# 49654        98              7
# 49655       128              3
# 49656        83              4
# 49657         2             16
# 49658        17             13
# 49660       134              5
# 49664        45             19
# 49665        61             19
# 49669       106             12
# 49670        45             19
# 49672       129              1
# 49676        59             15
# 49677       129              1
# 49678        61             19
# 49679        89             13
# 49681        98              7
# 49682        83              4
# 49683       124              5
# 49684        42              1
#
# [25609 rows x 4 columns]

# %%
concat = " ".join(names)
single_words = re.sub("[^\w]", " ",  concat).split()
bought_names = np.unique(single_words)

bought_names = filter_and_normalize_list(bought_names)
print(bought_names)
# Out:
# ['aaa', 'abate', 'abc', 'abl', 'abruzzese', 'absorbency', 'absorbenncy', 'absorber', 'abuelita', 'abundant', 'acacia', 'acai', 'acaí', 'accent', 'aceita', 'ache', 'achiote', 'acid', 'acidophilu', 'acini', 'acme', 'acorn', 'acting', 'active', 'activedry', 'activia', 'activity', 'add', 'added', 'ade', 'adhesive', 'adige', 'adobo', 'aduki', 'advanced', 'adzuki', 'aerosol', 'affi', 'african', 'after', 'agar', 'agave', 'age', 'aged', 'agen', 'ag', 'ahi', 'ahoy', 'aid', 'ailoi', 'aioli', 'aiolo', 'air', 'aji', 'aka', 'akoma', 'alaria', 'alarm', 'alaska', 'alaskan', 'alba', 'albacore', 'albacoretuna', 'albarino', 'alcaparrado', 'alcohol', 'alcoholic', 'alder', 'alderwood', 'ale', 'alehouse', 'aleppo', 'aleve', 'alexander', 'alfabeto', 'alfalfa', 'alfredo', 'alfresco', 'algae', 'alice', 'alive', 'alkaline', 'alkalize', 'all', 'alla', 'allspice', 'allure', 'almnd', 'almond', 'almondmilk', 'almond', 'almonette', 'almost', 'aloe', 'aloha', 'aloo', 'alpha', 'alphabet', 'alphabet', 'alphatot', 'alphonso', 'alpine', 'alsace', 'alta', 'alternative', 'alto', 'alto', 'alum', 'aluminum', 'alway', 'amador', 'amaranth', 'amaretti', 'amaretto', 'amarilla', 'amarillo', 'amaz', 'amazake', 'amazin', 'amazing', 'amazin', 'amazon', 'amber', 'ambrosia', 'amchoor', 'america', 'american', 'americana', 'americano', 'amino', 'amish', 'amond', 'amontillado', 'amore', 'amour', 'amsterdam', 'anaheim', 'ancho', 'ancho', 'anchovy', 'anchovy', 'ancient', 'and', 'anderson', 'and', 'andouille', 'anejo', 'angel', 'angu', 'animal', 'animalito', 'animal', 'anise', 'anisette', 'anjou', 'ann', 'annatto', 'anne', 'annie', 'ant', 'anti', 'antibacterial', 'antibiotic', 'antifungal', 'antimo', 'antioxidant', 'antioxidant', 'antipasto', 'anxiety', 'any', 'anytime', 'aop', 'aparagu', 'apart', 'aperitif', 'apertif', 'api', 'apitherapy', 'apiwellnes', 'appeal', 'appetizer', 'appetizer', 'apple', 'appleapple', 'appleberry', 'applejack', 'appl', 'applesauce', 'applewood', 'appley', 'apricot', 'apricot', 'aqua', 'aquafaba', 'arabella', 'arame', 'arbequina', 'arbol', 'arborio', 'arbosana', 'archway', 'arctic', 'ardeche', 'area', 'argentina', 'aril', 'arizona', 'armagnac', 'armenian', 'armor', 'arnold', 'aromat', 'aromatic', 'arou', 'arrabbiata', 'arrabiata', 'arrabiatta', 'arrangement', 'arrowroot', 'arroz', 'arthur', 'artic', 'artichoke', 'artichok', 'artifically', 'artificial', 'artificially', 'artiheart', 'artisan', 'artisanal', 'arugula', 'asada', 'asado', 'ascend', 'ash', 'ashwagandha', 'asiago', 'asian', 'asparagu', 'asparation', 'aspen', 'aspic', 'aspirator', 'assemble', 'assorted', 'assortment', 'asti', 'atar', 'ataulfo', 'athlete', 'atlantic', 'aubergine', 'aunt', 'aurora', 'aussie', 'austin', 'australia', 'australian', 'authentic', 'autumn', 'avant', 'avenger', 'avocado', 'avocado', 'awaken', 'awatere', 'away', 'awesome', 'awesomesauce', 'azafran', 'aztec', 'baba', 'babaganu', 'babaghannouj', 'baby', 'babka', 'baby', 'babyback', 'babybel', 'babyrub', 'bac', 'baci', 'back', 'backfin', 'backpacker', 'bacon', 'bada', 'bag', 'bagel', 'bagel', 'bagged', 'bag', 'baguette', 'baguett', 'baharat', 'bai', 'bailey', 'baingan', 'baiocchi', 'bait', 'baixa', 'baja', 'bake', 'baked', 'baker', 'bakery', 'baker', 'bakery', 'bakin', 'baking', 'baklava', 'balance', 'balanced', 'ball', 'ball', 'balm', 'balsamic', 'balsamico', 'bamboo', 'banana', 'bananaberry', 'banana', 'bandag', 'bandito', 'band', 'bang', 'banger', 'bangkok', 'banh', 'banner', 'baobab', 'bar', 'baratte', 'barbacoa', 'barbado', 'barbara', 'barbecue', 'barbeque', 'barbera', 'barbie', 'barcelona', 'bare', 'bareskin', 'barilla', 'barista', 'bark', 'barley', 'barn', 'barnum', 'barolo', 'barramundi', 'barrel', 'bar', 'bartlett', 'base', 'based', 'bash', 'basic', 'basil', 'basilico', 'basket', 'basmati', 'basque', 'baste', 'batampte', 'batch', 'bath', 'bathed', 'batter', 'battered', 'battery', 'battery', 'bava', 'bavarian', 'bay', 'bayley', 'bbq', 'bead', 'beam', 'beam', 'bean', 'beanee', 'bean', 'bear', 'bearly', 'bearnaise', 'be ...

# %%
products['product_name'] = products['product_name'].apply(lambda x: x.split(' '))

# %%
products['product_name'] = products['product_name'].apply(filter_and_normalize_list)

# %% [markdown]
# ## Products that appear in recipes

# %%
recipes = pd.read_json("../../data/recipes/train.json")
fl = flatten(list(recipes["ingredients"]))
ingr = " ".join(fl)

recipes_products = re.sub("[^\w]", " ",  ingr).split()
recipes_products = filter_and_normalize_list(recipes_products)

# %%
Counter(recipes_products).most_common(2000)
# Out:
# [('pepper', 27187),
#  ('salt', 24462),
#  ('oil', 23344),
#  ('onion', 19242),
#  ('garlic', 18941),
#  ('ground', 18271),
#  ('fresh', 17853),
#  ('sauce', 13129),
#  ('sugar', 12502),
#  ('cheese', 11776),
#  ('chicken', 11557),
#  ('tomato', 11205),
#  ('olive', 10920),
#  ('black', 10753),
#  ('water', 9790),
#  ('red', 9189),
#  ('green', 9089),
#  ('egg', 9039),
#  ('flour', 8851),
#  ('butter', 8648),
#  ('powder', 8290),
#  ('chopped', 7884),
#  ('clov', 7557),
#  ('juice', 7146),
#  ('white', 6915),
#  ('cream', 6096),
#  ('rice', 6073),
#  ('cilantro', 5950),
#  ('milk', 5872),
#  ('lemon', 5796),
#  ('vegetable', 5645),
#  ('leav', 5580),
#  ('large', 5396),
#  ('ginger', 5388),
#  ('corn', 5325),
#  ('dried', 5316),
#  ('vinegar', 4972),
#  ('lime', 4942),
#  ('soy', 4888),
#  ('all', 4839),
#  ('purpose', 4831),
#  ('cumin', 4644),
#  ('broth', 4504),
#  ('chili', 4318),
#  ('wine', 4315),
#  ('bell', 4275),
#  ('parsley', 4150),
#  ('seed', 4038),
#  ('bean', 3994),
#  ('sesame', 3518),
#  ('breast', 3335),
#  ('grated', 3280),
#  ('carrot', 3232),
#  ('kosher', 3180),
#  ('basil', 3106),
#  ('extra', 3085),
#  ('beef', 3081),
#  ('dry', 3046),
#  ('brown', 3015),
#  ('baking', 2972),
#  ('potato', 2950),
#  ('parmesan', 2947),
#  ('unsalted', 2943),
#  ('paste', 2924),
#  ('chily', 2794),
#  ('virgin', 2766),
#  ('oregano', 2752),
#  ('boneles', 2730),
#  ('shredded', 2695),
#  ('tortilla', 2640),
#  ('cinnamon', 2612),
#  ('fat', 2612),
#  ('cooking', 2480),
#  ('thyme', 2474),
#  ('pork', 2465),
#  ('mushroom', 2422),
#  ('shrimp', 2367),
#  ('yellow', 2299),
#  ('seasoning', 2297),
#  ('bread', 2283),
#  ('chile', 2280),
#  ('diced', 2276),
#  ('low', 2265),
#  ('sodium', 2259),
#  ('skinles', 2241),
#  ('vanilla', 2225),
#  ('coconut', 2218),
#  ('coriander', 2174),
#  ('cayenne', 2140),
#  ('celery', 2136),
#  ('minced', 2100),
#  ('bay', 2095),
#  ('whole', 2071),
#  ('leaf', 2070),
#  ('spray', 2018),
#  ('crushed', 2005),
#  ('sour', 1954),
#  ('scallion', 1952),
#  ('flak', 1932),
#  ('paprika', 1911),
#  ('stock', 1909),
#  ('purple', 1898),
#  ('starch', 1896),
#  ('hot', 1890),
#  ('cheddar', 1852),
#  ('fish', 1828),
#  ('mustard', 1781),
#  ('jalapeno', 1771),
#  ('orange', 1764),
#  ('extract', 1762),
#  ('peanut', 1731),
#  ('sweet', 1661),
#  ('curry', 1623),
#  ('frozen', 1602),
#  ('shallot', 1500),
#  ('sea', 1500),
#  ('light', 1477),
#  ('pea', 1473),
#  ('mozzarella', 1426),
#  ('noodl', 1415),
#  ('honey', 1403),
#  ('spinach', 1389),
#  ('cooked', 1381),
#  ('italian', 1379),
#  ('heavy', 1373),
#  ('oliv', 1364),
#  ('salsa', 1347),
#  ('mint', 1328),
#  ('sliced', 1325),
#  ('avocado', 1306),
#  ('canola', 1278),
#  ('cabbage', 1254),
#  ('pasta', 1239),
#  ('bacon', 1213),
#  ('lettuce', 1209),
#  ('sausage', 1199),
#  ('yogurt', 1167),
#  ('cucumber', 1167),
#  ('almond', 1149),
#  ('yolk', 1131),
#  ('flat', 1124),
#  ('fillet', 1118),
#  ('nutmeg', 1091),
#  ('dark', 1083),
#  ('masala', 1070),
#  ('soda', 1056),
#  ('freshly', 1054),
#  ('free', 1051),
#  ('halv', 1009),
#  ('buttermilk', 1008),
#  ('crumb', 999),
#  ('plum', 992),
#  ('jack', 972),
#  ('turmeric', 965),
#  ('reduced', 962),
#  ('rib', 959),
#  ('steak', 940),
#  ('whit', 939),
#  ('zucchini', 931),
#  ('granulated', 930),
#  ('garam', 927),
#  ('zest', 893),
#  ('plain', 880),
#  ('toasted', 862),
#  ('chocolate', 862),
#  ('rosemary', 858),
#  ('whipping', 841),
#  ('peeled', 836),
#  ('smoked', 833),
#  ('grain', 833),
#  ('thigh', 830),
#  ('peppercorn', 821),
#  ('sprig', 806),
#  ('mayonaise', 781),
#  ('baby', 776),
#  ('stick', 770),
#  ('tumeric', 763),
#  ('yeast', 758),
#  ('cardamom', 747),
#  ('chinese', 743),
#  ('half', 731),
#  ('thai', 725),
#  ('roasted', 724),
#  ('coarse', 723),
#  ('ricotta', 723),
#  ('worcestershire', 713),
#  ('raisin', 705),
#  ('long', 690),
#  ('ham', 677),
#  ('mix', 670),
#  ('cider', 669),
#  ('fennel', 658),
#  ('wheat', 656),
#  ('taco', 653),
#  ('kernel', 651),
#  ('cherry', 642),
#  ('medium', 640),
#  ('chil', 637),
#  ('meat', 636),
#  ('feta', 635),
#  ('chiv', 630),
#  ('sherry', 630),
#  ('turkey', 627),
#  ('tofu', 626),
#  ('clove', 620),
#  ('syrup', 618),
#  ('shiitake', 614),
#  ('ice', 609),
#  ('pecan', 609),
#  ('eggplant', 607),
#  ('balsamic', 607),
#  ('lamb', 593),
#  ('monterey', 592),
#  ('oyster', 587),
#  ('warm', 585),
#  ('dijon', 572),
#  ('chip', 568),
#  ('condensed', 565),
#  ('lean', 563),
#  ('powdered', 556),
#  ('root', 555),
#  ('allspice', 555),
#  ('caper', 552),
#  ('les', 549),
#  ('finely', 549),
#  ('serrano', 547),
#  ('unsweetened', 546),
#  ('cold', 536),
#  ('roast', 524),
#  ('broccoli', 519),
#  ('mexican', 511),
#  ('cornmeal', 510),
#  ('slic', 509),
#  ('and', 504),
#  ('ketchup', 504),
#  ('mirin', 503),
#  ('soup', 494),
#  ('greek', 492),
#  ('wedg', 488),
#  ('saffron', 487),
#  ('spring', 487),
#  ('skim', 476),
#  ('chickpea', 475),
#  ('dough', 474),
#  ('sharp', 472),
#  ('sage', 472),
#  ('peel', 468),
#  ('boiling', 464),
#  ('beansprout', 454),
#  ('spaghetti', 449),
#  ('squash', 445),
#  ('leek', 444),
#  ('dill', 444),
#  ('hoisin', 433),
#  ('reggiano', 431),
#  ('apple', 429),
#  ('golden', 420),
#  ('parmigiano', 417),
#  ('dressing', 416),
#  ('shoulder', 411),
#  ('sausag', 410),
#  ('cracked', 409),
#  ('kalamata', 406),
#  ('enchilada', 401),
#  ('shell', 399),
#  ('pitted', 397),
#  ('appl', 397),
#  ('confectioner', 396),
#  ('cajun', 396),
#  ('anise', 395),
#  ('part', 395),
#  ('cocoa', 393),
#  ('wrapper', 389),
#  ('meal', 388),
#  ('spice', 381),
#  ('crumbl', 379),
#  ('firm', 379),
#  ('active', 379),
#  ('fine', 376),
#  ('tenderloin', 376),
#  ('roll', 373),
#  ('shortening', 369),
#  ('pineapple', 368),
#  ('lemongras', 364),
#  ('peach', 364),
#  ('chipotle', 363),
#  ('style', 363),
#  ('canned', 360),
#  ('nut', 359),
#  ('creole', 357),
#  ('pastry', 357),
#  ('pizza', 356),
#  ('sweetened', 355),
#  ('chop', 354),
#  ('mango', 349),
#  ('cashew', 349),
#  ('asparagu', 348),
#  ('pinenut', 348),
#  ('basmati', 346),
#  ('sake', 345),
#  ('salad', 344),
#  ('baguette', 338),
#  ('lentil', 337),
#  ('cake', 336),
#  ('clam', 336),
#  ('walnut', 332),
#  ('okra', 332),
#  ('tomatillo', 332),
#  ('romaine', 329),
#  ('poblano', 326),
#  ('anchovy', 325),
#  ('penne', 324),
#  ('floret', 324),
#  ('radish', 321),
#  ('salmon', 318),
#  ('thread', 317),
#  ('french', 316),
#  ('adobo', 314),
#  ('banana', 313),
#  ('ghee', 307),
#  ('kidney', 307),
#  ('cauliflower', 306),
#  ('beer', 304),
#  ('grit', 302),
#  ('sriracha', 298),
#  ('lasagna', 297),
#  ('pod', 295),
#  ('refried', 295),
#  ('arborio', 294),
#  ('andouille', 293),
#  ('five', 293),
#  ('grape', 290),
#  ('romano', 287),
#  ('vegetabl', 286),
#  ('prosciutto', 285),
#  ('leg', 283),
#  ('loin', 281),
#  ('herb', 281),
#  ('instant', 279),
#  ('yoghurt', 279),
#  ('sirloin', 278),
#  ('melted', 277),
#  ('russet', 275),
#  ('shaoxing', 273),
#  ('crab', 273),
#  ('whiskey', 273),
#  ('miso', 270),
#  ('chorizo', 266),
#  ('crust', 264),
#  ('chestnut', 262),
#  ('bouillon', 261),
#  ('gold', 260),
#  ('flank', 259),
#  ('star', 259),
#  ('margarine', 258),
#  ('strawberry', 257),
#  ('linguine', 256),
#  ('apricot', 255),
#  ('evaporated', 251),
#  ('heart', 251),
#  ('goat', 251),
#  ('blend', 247),
#  ('nonfat', 247),
#  ('rum', 246),
#  ('raspberry', 245),
#  ('asian', 245),
#  ('ancho', 245),
#  ('tarragon', 245),
#  ('purée', 244),
#  ('napa', 243),
#  ('self', 243),
#  ('rising', 241),
#  ('marinara', 238),
#  ('coffee', 238),
#  ('chuck', 236),
#  ('pie', 232),
#  ('panko', 229),
#  ('english', 228),
#  ('roma', 227),
#  ('liqueur', 226),
#  ('bulb', 225),
#  ('yukon', 225),
#  ('wedge', 225),
#  ('cub', 224),
#  ('choy', 224),
#  ('arugula', 224),
#  ('packed', 224),
#  ('seasoned', 221),
#  ('swis', 219),
#  ('pecorino', 219),
#  ('pure', 219),
#  ('pear', 218),
#  ('breadcrumb', 217),
#  ('pesto', 215),
#  ('tea', 215),
#  ('food', 214),
#  ('base', 212),
#  ('queso', 212),
#  ('spic', 211),
#  ('bok', 209),
#  ('mixed', 209),
#  ('couscou', 206),
#  ('cannellini', 206),
#  ('tabasco', 206),
#  ('tamarind', 205),
#  ('drain', 204),
#  ('kale', 204),
#  ('pinto', 203),
#  ('bourbon', 202),
#  ('pimento', 201),
#  ('rind', 200),
#  ('salted', 199),
#  ('scallop', 199),
#  ('sun', 199),
#  ('chipotl', 198),
#  ('eyed', 196),
#  ('stewed', 196),
#  ('old', 195),
#  ('veal', 193),
#  ('guacamole', 192),
#  ('pumpkin', 191),
#  ('button', 190),
#  ('snow', 189),
#  ('tuna', 189),
#  ('collard', 188),
#  ('cottage', 188),
#  ('unbleached', 187),
#  ('short', 183),
#  ('refrigerated', 182),
#  ('mussel', 181),
#  ('slivered', 181),
#  ('tartar', 180),
#  ('pancetta', 180),
#  ('brandy', 179),
#  ('puff', 177),
#  ('mayonnaise', 176),
#  ('fresco', 175),
#  ('butternut', 175),
#  ('semisweet', 174),
#  ('dal', 173),
#  ('sprout', 172),
#  ('vermicelli', 172),
#  ('small', 170),
#  ('round', 169),
#  ('whipped', 169),
#  ('wonton', 169),
#  ('iceberg', 168),
#  ('fenugreek', 168),
#  ('marjoram', 168),
#  ('provolone', 167),
#  ('country', 167),
#  ('bone', 166),
#  ('jasmine', 165),
#  ('lard', 165),
#  ('soft', 165),
#  ('hominy', 162),
#  ('pita', 162),
#  ('dashi', 162),
#  ('cut', 161),
#  ('fettucine', 159),
#  ('turnip', 157),
#  ('palm', 157),
#  ('spanish', 157),
#  ('with', 157),
#  ('polenta', 157),
#  ('tequila', 156),
#  ('currant', 155),
#  ('crème', 155),
#  ('non', 155),
#  ('artichoke', 153),
#  ('hazelnut', 153),
#  ('garbanzo', 152),
#  ('molas', 152),
#  ('shoot', 152),
#  ('quinoa', 151),
#  ('daikon', 151),
#  ('bittersweet', 151),
#  ('cracker', 150),
#  ('sheet', 150),
#  ('mascarpone', 149),
#  ('gelatin', 149),
#  ('caster', 148),
#  ('firmly', 147),
#  ('nori', 147),
#  ('maple', 146),
#  ('chunky', 146),
#  ('fraîche', 146),
#  ('verde', 144),
#  ('duck', 143),
#  ('wing', 143),
#  ('japanese', 143),
#  ('soften', 143),
#  ('cotija', 143),
#  ('pistachio', 142),
#  ('gochujang', 142),
#  ('prawn', 142),
#  ('szechwan', 142),
#  ('lower', 141),
#  ('fruit', 141),
#  ('cremini', 140),
#  ('boiled', 139),
#  ('kaffir', 139),
#  ('masa', 139),
#  ('bamboo', 138),
#  ('barbecue', 138),
#  ('beet', 138),
#  ('prepared', 137),
#  ('pearl', 136),
#  ('fontina', 136),
#  ('horseradish', 134),
#  ('artichok', 133),
#  ('curd', 129),
#  ('top', 129),
#  ('bun', 129),
#  ('liquid', 129),
#  ('catfish', 128),
#  ('hard', 128),
#  ('macaroni', 128),
#  ('phyllo', 126),
#  ('mung', 126),
#  ('cranberry', 125),
#  ('espresso', 125),
#  ('orzo', 125),
#  ('belly', 124),
#  ('butt', 124),
#  ('concentrate', 123),
#  ('semolina', 122),
#  ('creamy', 121),
#  ('chilly', 121),
#  ('casing', 121),
#  ('chard', 121),
#  ('piec', 121),
#  ('marsala', 121),
#  ('liver', 120),
#  ('che', 120),
#  ('paneer', 120),
#  ('biscuit', 120),
#  ('berry', 119),
#  ('granny', 119),
#  ('smith', 119),
#  ('gingerroot', 119),
#  ('vidalia', 119),
#  ('mild', 119),
#  ('shank', 119),
#  ('crawfish', 118),
#  ('drumstick', 118),
#  ('kimchi', 118),
#  ('lump', 117),
#  ('porcini', 114),
#  ('sunflower', 114),
#  ('nectar', 114),
#  ('granul', 113),
#  ('chutney', 113),
#  ('watercres', 112),
#  ('jumbo', 112),
#  ('tamari', 111),
#  ('oat', 111),
#  ('stew', 111),
#  ('ranch', 110),
#  ('cod', 110),
#  ('unflavored', 110),
#  ('soba', 110),
#  ('hock', 109),
#  ('tapioca', 109),
#  ('cap', 109),
#  ('bow', 109),
#  ('raw', 108),
#  ('angel', 106),
#  ('asafoetida', 106),
#  ('seedles', 105),
#  ('cutlet', 104),
#  ('gras', 104),
#  ('cornflour', 103),
#  ('crumbled', 103),
#  ('sauc', 103),
#  ('blanched', 103),
#  ('tie', 103),
#  ('dripping', 102),
#  ('flavored', 102),
#  ('tilapia', 102),
#  ('organic', 101),
#  ('blackberry', 101),
#  ('harina', 100),
#  ('gruyere', 99),
#  ('pepperoni', 99),
#  ('morsel', 99),
#  ('fig', 99),
#  ('hair', 99),
#  ('pickled', 98),
#  ('halibut', 98),
#  ('marinade', 96),
#  ('elbow', 96),
#  ('salami', 95),
#  ('ripe', 95),
#  ('orang', 94),
#  ('wasabi', 94),
#  ('jam', 94),
#  ('cognac', 94),
#  ('coloring', 94),
#  ('husk', 94),
#  ('bonito', 92),
#  ('sushi', 92),
#  ('topping', 91),
#  ('guajillo', 91),
#  ('link', 90),
#  ('table', 90),
#  ('gluten', 90),
#  ('blueberry', 90),
#  ('sandwich', 89),
#  ('crema', 88),
#  ('galangal', 88),
#  ('jicama', 88),
#  ('amchur', 87),
#  ('quickcooking', 86),
#  ('steamed', 86),
#  ('rigatoni', 86),
#  ('squid', 86),
#  ('caraway', 86),
#  ('sourdough', 85),
#  ('asiago', 85),
#  ('edamame', 84),
#  ('pickl', 84),
#  ('snapper', 84),
#  ('agave', 84),
#  ('stem', 84),
#  ('skimmed', 83),
#  ('semi', 83),
#  ('ear', 83),
#  ('crabmeat', 83),
#  ('vodka', 83),
#  ('preserv', 82),
#  ('wild', 82),
#  ('mace', 81),
#  ('piecrust', 81),
#  ('substitute', 81),
#  ('prun', 81),
#  ('alfredo', 81),
#  ('blue', 80),
#  ('hamburger', 80),
#  ('colby', 80),
#  ('irish', 80),
#  ('pico', 79),
#  ('gallo', 79),
#  ('grapeseed', 79),
#  ('cured', 79),
#  ('poppy', 79),
#  ('new', 79),
#  ('graham', 78),
#  ('tortellini', 78),
#  ('bon', 78),
#  ('bas', 78),
#  ('vinaigrette', 77),
#  ('slaw', 76),
#  ('double', 74),
#  ('superfine', 74),
#  ('date', 74),
#  ('paper', 74),
#  ('skirt', 73),
#  ('preserved', 73),
#  ('candied', 73),
#  ('whip', 73),
#  ('ramen', 73),
#  ('lima', 73),
#  ('habanero', 73),
#  ('methi', 72),
#  ('gorgonzola', 72),
#  ('brisket', 72),
#  ('urad', 71),
#  ('eye', 71),
#  ('baked', 71),
#  ('spread', 71),
#  ('picante', 70),
#  ('mini', 70),
#  ('bag', 70),
#  ('cachaca', 70),
#  ('harissa', 69),
#  ('dat', 69),
#  ('pickle', 69),
#  ('port', 69),
#  ('parsnip', 68),
#  ('portabello', 68),
#  ('mashed', 68),
#  ('thick', 68),
#  ('lobster', 68),
#  ('knorr', 68),
#  ('brewed', 67),
#  ('grating', 67),
#  ('rotini', 67),
#  ('konbu', 66),
#  ('teriyaki', 66),
#  ('rotisserie', 66),
#  ('tahini', 65),
#  ('split', 65),
#  ('capsicum', 65),
#  ('poultry', 65),
#  ('wafer', 65),
#  ('skin', 65),
#  ('provence', 65),
#  ('mein', 64),
#  ('marshmallow', 64),
#  ('manchego', 64),
#  ('spear', 64),
#  ('udon', 64),
#  ('vermouth', 64),
#  ('crimini', 64),
#  ('processed', 64),
#  ('dri', 63),
#  ('california', 63),
#  ('fettuccine', 63),
#  ('vietnamese', 63),
#  ('flower', 63),
#  ('hungarian', 63),
#  ('yam', 63),
#  ('dumpling', 63),
#  ('roasting', 63),
#  ('natural', 62),
#  ('radicchio', 62),
#  ('brine', 62),
#  ('sambal', 62),
#  ('sprinkl', 62),
#  ('littleneck', 62),
#  ('gnocchi', 61),
#  ('pudding', 61),
#  ('gruyère', 61),
#  ('bird', 61),
#  ('cooky', 61),
#  ('papaya', 60),
#  ('grapefruit', 60),
#  ('dipping', 60),
#  ('bottled', 60),
#  ('gravy', 60),
#  ('scotch', 60),
#  ('deveined', 60),
#  ('escarole', 60),
#  ('stuffed', 60),
#  ('malt', 59),
#  ('for', 59),
#  ('relish', 59),
#  ('pomegranate', 59),
#  ('file', 59),
#  ('seaweed', 58),
#  ('jerk', 58),
#  ('boston', 58),
#  ('center', 58),
#  ('rock', 58),
#  ('champagne', 58),
#  ('hellmann', 58),
#  ('navel', 58),
#  ('beaten', 58),
#  ('gram', 58),
#  ('savoy', 57),
#  ('cane', 57),
#  ('glutinou', 57),
#  ('prepar', 57),
#  ('best', 57),
#  ('fry', 56),
#  ('back', 56),
#  ('quick', 56),
#  ('slice', 55),
#  ('silken', 55),
#  ('range', 55),
#  ('haricot', 55),
#  ('filet', 55),
#  ('seafood', 55),
#  ('homemade', 55),
#  ('whitefish', 55),
#  ('vert', 54),
#  ('fusilli', 54),
#  ('barley', 53),
#  ('crusty', 53),
#  ('kielbasa', 53),
#  ('flaked', 53),
#  ('cornbread', 53),
#  ('chunk', 53),
#  ('paso', 52),
#  ('tart', 52),
#  ('ulek', 52),
#  ('kasuri', 51),
#  ('rubbed', 51),
#  ('asafetida', 51),
#  ('clarified', 51),
#  ('anaheim', 51),
#  ('marin', 51),
#  ('great', 50),
#  ('northern', 50),
#  ('turbinado', 50),
#  ('muffin', 50),
#  ('gari', 50),
#  ('vine', 50),
#  ('nonstick', 50),
#  ('shelled', 50),
#  ('mayonnai', 50),
#  ('arbol', 50),
#  ('spicy', 49),
#  ('softened', 49),
#  ('drained', 49),
#  ('store', 49),
#  ('bought', 49),
#  ('crescent', 49),
#  ('ciabatta', 49),
#  ('ready', 49),
#  ('uncook', 49),
#  ('finger', 49),
#  ('candy', 49),
#  ('endive', 49),
#  ('rocket', 49),
#  ('added', 49),
#  ('rabe', 48),
#  ('fried', 48),
#  ('watermelon', 48),
#  ('marmalade', 48),
#  ('cocktail', 48),
#  ('jeera', 47),
#  ('oven', 47),
#  ('pickling', 47),
#  ('ladyfinger', 47),
#  ('enokitake', 47),
#  ('tip', 46),
#  ('ravioli', 46),
#  ('bonnet', 46),
#  ('truffle', 46),
#  ('essence', 46),
#  ('grap', 46),
#  ('club', 45),
#  ('buckwheat', 45),
#  ('regular', 45),
#  ('kraft', 45),
#  ('dusting', 45),
#  ('sweetener', 45),
#  ('chaat', 45),
#  ('real', 45),
#  ('ra', 44),
#  ('hanout', 44),
#  ('jamaican', 44),
#  ('crouton', 44),
#  ('epazote', 43),
#  ('has', 43),
#  ('marnier', 43),
#  ('orecchiette', 43),
#  ('hothouse', 43),
#  ('won', 43),
#  ('ton', 43),
#  ('mandarin', 42),
#  ('fava', 42),
#  ('safflower', 42),
#  ('caramel', 42),
#  ('plantain', 42),
#  ('simple', 42),
#  ('stir', 42),
#  ('deli', 41),
#  ('thin', 41),
#  ('vegan', 41),
#  ('pasilla', 41),
#  ('jelly', 41),
#  ('ragu', 41),
#  ('tostada', 40),
#  ('jaggery', 40),
#  ('deliciou', 40),
#  ('meatball', 40),
#  ('naan', 39),
#  ('breakfast', 39),
#  ('frosting', 39),
#  ('glas', 39),
#  ('sparerib', 39),
#  ('sweeten', 39),
#  ('saltin', 39),
#  ('brussel', 39),
#  ('gai', 39),
#  ('fermented', 39),
#  ('pine', 39),
#  ('pink', 39),
#  ('american', 39),
#  ('coleslaw', 38),
#  ('stuffing', 38),
#  ('rose', 38),
#  ('ziti', 38),
#  ('crystallized', 38),
#  ('lan', 38),
#  ('bitter', 38),
#  ('key', 38),
#  ('belgian', 38),
#  ('neutral', 38),
#  ('kiwi', 37),
#  ('wood', 37),
#  ('korean', 37),
#  ('bertolli', 37),
#  ('brie', 37),
#  ('dog', 37),
#  ('rub', 37),
#  ('gyoza', 37),
#  ('heirloom', 37),
#  ('hen', 37),
#  ('madeira', 36),
#  ('dillweed', 36),
#  ('salata', 36),
#  ('grate', 36),
#  ('madra', 36),
#  ('amaretto', 36),
#  ('melon', 36),
#  ('smoke', 36),
#  ('oxtail', 36),
#  ('soybean', 36),
#  ('filling', 36),
#  ('original', 36),
#  ('triple', 35),
#  ('sec', 35),
#  ('strip', 35),
#  ('frond', 35),
#  ('flavor', 35),
#  ('arrowroot', 34),
#  ('ripened', 34),
#  ('loaf', 34),
#  ('tangerine', 34),
#  ('rolled', 34),
#  ('trout', 33),
#  ('fryer', 33),
#  ('gouda', 33),
#  ('cak', 33),
#  ('ale', 33),
#  ('cornichon', 33),
#  ('fajita', 33),
#  ('colouring', 32),
#  ('quarter', 32),
#  ('cereal', 32),
#  ('sticky', 32),
#  ('puree', 32),
#  ('summer', 32),
#  ('glaze', 32),
#  ('corned', 32),
#  ('chervil', 32),
#  ('calamansi', 32),
#  ('velveeta', 32),
#  ('chow', 32),
#  ('chayot', 32),
#  ('glace', 31),
#  ('straw', 31),
#  ('wide', 31),
#  ('rotel', 31),
#  ('tandoori', 31),
#  ('waxy', 31),
#  ('cook', 31),
#  ('togarashi', 31),
#  ('tender', 31),
#  ('rotelle', 31),
#  ('cube', 31),
#  ('flavoring', 31),
#  ('amino', 30),
#  ('manicotti', 30),
#  ('grand', 30),
#  ('thawed', 30),
#  ('loosely', 30),
#  ('bulgur', 30),
#  ('toast', 30),
#  ('mahi', 30),
#  ('gochugaru', 30),
#  ('navy', 29),
#  ('blossom', 29),
#  ('philadelphia', 29),
#  ('lager', 29),
#  ('genoa', 29),
#  ('nutritional', 29),
#  ('bbq', 29),
#  ('msg', 29),
#  ('sauerkraut', 29),
#  ('stewing', 29),
#  ('not', 29),
#  ('creme', 28),
#  ('rye', 28),
#  ('tiger', 28),
#  ('ditalini', 28),
#  ('swordfish', 28),
#  ('guinnes', 27),
#  ('medjool', 27),
#  ('shiso', 27),
#  ('niçoise', 27),
#  ('asadero', 27),
#  ('veggy', 27),
#  ('stone', 27),
#  ('stilton', 27),
#  ('splenda', 27),
#  ('can', 27),
#  ('flatbread', 27),
#  ('cornish', 27),
#  ('shucked', 27),
#  ('full', 27),
#  ('boil', 26),
#  ('demi', 26),
#  ('season', 26),
#  ('curly', 26),
#  ('cubed', 26),
#  ('lumpia', 26),
#  ('kirby', 26),
#  ('stout', 26),
#  ('bouquet', 26),
#  ('haddock', 26),
#  ('chilli', 26),
#  ('burgundy', 26),
#  ('dinner', 25),
#  ('pappardelle', 25),
#  ('campbell', 25),
#  ...]

# %%
prohibited_words = ["salt", "fresh", "chopped", "large", "all", "purpose", "unsalted", "virgin", "traditional", "natural", "whole", "frozen", "half", "evaporated"]
recipes_products = filter(lambda x: x not in prohibited_words, recipes_products)

# %%
recipes_products = list(recipes_products)
recipes_products = np.unique(recipes_products)
recipes_products
# Out:
# array(['abalone', 'abbamele', 'absinthe', ..., 'ziti', 'zucchini', 'épic'],
#       dtype='<U16')

# %%
common = list(set(bought_names) & set(recipes_products))
prohibited_words = ['organic', 'original', 'water', 'with', 'of', 'and', 'no', 'a', 'mr', 'style']
common = filter(lambda x: x not in prohibited_words, common)
common = list(common)

# %%
len(common)
# Out:
# 1839

# %%
def filer_products(words):
    words = [word for word in words if word in common]
    return ' '.join(words)

# %%
products.product_name = products.product_name.map(filer_products)
products = products[products.product_name != ""]
products.to_csv("../../data/instacart/products_cropped.csv")

# %%
recipes.ingredients = recipes.ingredients.map(lambda x: " ".join(x))
recipes.ingredients = recipes.ingredients.map(lambda x: x.split(" "))
recipes.ingredients = recipes.ingredients.map(filer_products)
recipes = recipes[recipes.ingredients != ""]
recipes.to_csv("../../data/instacart/recipes_cropped.csv")
